# %% [markdown]
# # Corporate-Grade Deep EDA -- Step-By-Step
#
# ### Superstone Data Set

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# #### 1) Import Dataset

# %%
df=pd.read_csv('C:\\Users\\Ayushi Joshi\\OneDrive\\Documents\\DataAnalyticsProject\\Superstone-Data-Analysis\\Dataset\\Superstone_Management_System.csv')

# %% [markdown]
# ### Basic Analysis

# %% [markdown]
# #### 2) Finding Head

# %%
df.head()
# Out:
#   Order Id  Order Date   Ship Date Customer Id    Customer Name  \
# 0  ORD1000  20-06-2026  26-06-2026     CUST881      Robert Bath
# 1  ORD1001   1/12/2024  19-01-2024     CUST758      Omaja Verma
# 2  ORD1002   12/6/2023  12/10/2023     CUST547       Waida Kibe
# 3  ORD1003  13-03-2026  19-03-2026     CUST284  Umang Natarajan
# 4  ORD1004  15-05-2024  21-05-2024     CUST148      Zarna Chana
#
#   Customer Segment Product Id   Product Name         Category Region  ...  \
# 0      Home Office    PROD143  Office Chairs        Furniture   West  ...
# 1        Corporate    PROD955        Monitor      Electronics  South  ...
# 2      Home Office    PROD447       Rice Bag          Grocery   West  ...
# 3         Consumer    PROD443    File Folder  Office Supplies  South  ...
# 4         Consumer    PROD638            Pen  Office Supplies   West  ...
#
#   Sales Amount Cost Price    Profit  Payment Mode  Delivery Status  \
# 0       9139.5    6766.17   2373.33          Cash         Returned
# 1      66160.0   35888.32  30271.68           UPI          Pending
# 2      38943.0   29684.69   9258.31          Cash          Pending
# 3      15473.6    9068.18   6405.42           UPI         Returned
# 4       9754.6    5605.26   4149.34          Cash          Pending
#
#                  Supplier Name               Supplier Email  Stock Left  \
# 0                     Mane PLC         shethcharvi@dash.com           4
# 1       Pal, Mishra and Kalita           samesh36@amble.com          22
# 2  Taneja, Aurora and Chaudhry       fhans@balakrishnan.com           0
# 3     Chokshi, Mutti and Borde      mittalhemang@yadav.info          35
# 4                     Mann Ltd  natarajanpallavi@halder.biz          24
#
#   Auto Reorder Reorder Quantity
# 0          Yes               43
# 1           No                0
# 2          Yes               38
# 3           No                0
# 4           No                0
#
# [5 rows x 25 columns]

# %% [markdown]
# #### 3) Finding Tail

# %%
df.tail()
# Out:
#     Order Id  Order Date   Ship Date Customer Id   Customer Name  \
# 995  ORD1995  18-12-2025  21-12-2025     CUST174     Harish Sura
# 996  ORD1996  23-04-2026  27-04-2026     CUST124    Balendra Kar
# 997  ORD1997   5/11/2025  15-05-2025     CUST442  Orinder Grover
# 998  ORD1998   7/10/2025  17-07-2025     CUST967  Fariq Zacharia
# 999  ORD1999    1/4/2026    1/5/2026     CUST890   Liam Nazareth
#
#     Customer Segment Product Id  Product Name         Category Region  ...  \
# 995        Corporate    PROD224          Sofa        Furniture  North  ...
# 996      Home Office    PROD628  Dining Table        Furniture  South  ...
# 997      Home Office    PROD616      Rice Bag          Grocery   East  ...
# 998         Consumer    PROD701   Study Table        Furniture  North  ...
# 999         Consumer    PROD952           Pen  Office Supplies  South  ...
#
#     Sales Amount Cost Price    Profit  Payment Mode  Delivery Status  \
# 995       7583.7    4614.93   2968.77   Credit Card        Cancelled
# 996      56048.1   39497.93  16550.17   Credit Card        Cancelled
# 997      70694.5   49722.06  20972.44          Cash        Cancelled
# 998      94992.0   52433.62  42558.38   Credit Card        Cancelled
# 999      13700.3    9248.96   4451.34          Cash         Returned
#
#                  Supplier Name               Supplier Email  Stock Left  \
# 995                Sampath Ltd           bedijyoti@bail.com          39
# 996                   Nair PLC          gchanda@chaudry.com          47
# 997               Chanda Group             jchandra@pal.org          46
# 998  Tata, Prabhakar and Patil  noahvenkatesh@chaudhary.biz           0
# 999            Sarraf and Sons        panchalupma@sule.info           8
#
#     Auto Reorder Reorder Quantity
# 995           No                0
# 996           No                0
# 997           No                0
# 998          Yes               39
# 999          Yes               40
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Finding all columns and dataset Shape

# %%
print(df.columns)
print(f"Shape is {df.shape}")
# Out:
# Index(['Order Id', 'Order Date', 'Ship Date', 'Customer Id', 'Customer Name',
#        'Customer Segment', 'Product Id', 'Product Name', 'Category', 'Region',
#        'State', 'City', 'Quantity', 'Unit Price', 'Discount %', 'Sales Amount',
#        'Cost Price', 'Profit', 'Payment Mode', 'Delivery Status',
#        'Supplier Name', 'Supplier Email', 'Stock Left', 'Auto Reorder',
#        'Reorder Quantity'],
#       dtype='object')
# Shape is (1000, 25)

# %% [markdown]
# ### Datatypes of columns in a dataset

# %%
print(type(df.columns))
# Out:
# <class 'pandas.core.indexes.base.Index'>

# %% [markdown]
# #### Finding Type

# %%
f'Data Type is :{type(df)}'
# Out:
# "Data Type is :<class 'pandas.core.frame.DataFrame'>"

# %% [markdown]
# #### Finding Data Type For each column

# %%
df.dtypes
# Out:
# Order Id             object
# Order Date           object
# Ship Date            object
# Customer Id          object
# Customer Name        object
# Customer Segment     object
# Product Id           object
# Product Name         object
# Category             object
# Region               object
# State                object
# City                 object
# Quantity              int64
# Unit Price            int64
# Discount %            int64
# Sales Amount        float64
# Cost Price          float64
# Profit              float64
# Payment Mode         object
# Delivery Status      object
# Supplier Name        object
# Supplier Email       object
# Stock Left            int64
# Auto Reorder         object
# Reorder Quantity      int64
# dtype: object

# %% [markdown]
# #### Finding Random sample from dataset.

# %%
df.sample(5)
# Out:
#     Order Id  Order Date   Ship Date Customer Id      Customer Name  \
# 146  ORD1146   9/10/2024   9/12/2024     CUST782  Chandresh Sanghvi
# 738  ORD1738  10/10/2024  15-10-2024     CUST358    Bhanumati Naidu
# 332  ORD1332  29-02-2024    3/1/2024     CUST848       Aarna Sunder
# 435  ORD1435  20-09-2023  27-09-2023     CUST230     Tamanna Narula
# 200  ORD1200  17-06-2025  23-06-2025     CUST203    Patrick Ganesan
#
#     Customer Segment Product Id Product Name         Category Region  ...  \
# 146      Home Office    PROD460        Mouse      Electronics   East  ...
# 738         Consumer    PROD444     Rice Bag          Grocery  North  ...
# 332      Home Office    PROD747          Pen  Office Supplies   West  ...
# 435         Consumer    PROD506          Pen  Office Supplies   East  ...
# 200      Home Office    PROD629  Cooking Oil          Grocery   West  ...
#
#     Sales Amount Cost Price    Profit  Payment Mode  Delivery Status  \
# 146      27825.6   13036.77  14788.83   Net Banking         Returned
# 738      11603.2    6818.72   4784.48          Cash         Returned
# 332      95576.0   39280.02  56295.98   Net Banking          Pending
# 435       6003.2    3673.40   2329.80           UPI         Returned
# 200      51579.0   27279.83  24299.17   Credit Card          Pending
#
#                Supplier Name                 Supplier Email  Stock Left  \
# 146  Bava, Manne and Acharya      qcomar@gokhale-tella.info          27
# 738             Sehgal Group     turvichakrabarti@sahni.com          28
# 332              Seth-Bhalla      matthewpandey@panchal.com           2
# 435              Kumar-Bhatt  manderisaiah@kaur-mallick.biz          22
# 200               D’Alia Inc       choudhuryfariq@nigam.com          45
#
#     Auto Reorder Reorder Quantity
# 146           No                0
# 738           No                0
# 332          Yes               43
# 435           No                0
# 200           No                0
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Finding summary of dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order Id          1000 non-null   object
#  1   Order Date        1000 non-null   object
#  2   Ship Date         1000 non-null   object
#  3   Customer Id       1000 non-null   object
#  4   Customer Name     1000 non-null   object
#  5   Customer Segment  1000 non-null   object
#  6   Product Id        1000 non-null   object
#  7   Product Name      1000 non-null   object
#  8   Category          1000 non-null   object
#  9   Region            1000 non-null   object
#  10  State             1000 non-null   object
#  11  City              1000 non-null   object
#  12  Quantity          1000 non-null   int64
#  13  Unit Price        1000 non-null   int64
#  14  Discount %        1000 non-null   int64
#  15  Sales Amount      1000 non-null   float64
#  16  Cost Price        1000 non-null   float64
#  17  Profit            1000 non-null   float64
#  18  Payment Mode      1000 non-null   object
#  19  Delivery Status   1000 non-null   object
#  20  Supplier Name     1000 non-null   object
#  21  Supplier Email    1000 non-null   object
#  22  Stock Left        1000 non-null   int64
#  23  Auto Reorder      1000 non-null   object
#  24  Reorder Quantity  1000 non-null   int64
# dtypes: float64(3), int64(5), object(17)
# memory usage: 195.4+ KB

# %% [markdown]
# #### Find all data

# %%
pd.set_option('display.max_rows',None)

# %% [markdown]
# #### Finding out description of dataset.

# %%
df.describe(include='object')
# Out:
#        Order Id Order Date Ship Date Customer Id Customer Name  \
# count      1000       1000      1000        1000          1000
# unique     1000        672       659         603           998
# top     ORD1000  3/11/2025  1/5/2025     CUST573   Faraj Palla
# freq          1          5         5           5             2
#
#        Customer Segment Product Id Product Name         Category Region  \
# count              1000       1000         1000             1000   1000
# unique                3        604           17                4      4
# top            Consumer    PROD827  Cooking Oil  Office Supplies  North
# freq                346          6          127              265    263
#
#             State        City Payment Mode Delivery Status Supplier Name  \
# count        1000        1000         1000            1000          1000
# unique         28         299            4               4           985
# top     Meghalaya  Aurangabad  Net Banking        Returned     Misra Ltd
# freq           47          15          280             262             2
#
#               Supplier Email Auto Reorder
# count                   1000         1000
# unique                  1000            2
# top     shethcharvi@dash.com           No
# freq                       1          797

# %% [markdown]
# #### Finding all null values in column

# %%
df.isnull().sum()
# Out:
# Order Id            0
# Order Date          0
# Ship Date           0
# Customer Id         0
# Customer Name       0
# Customer Segment    0
# Product Id          0
# Product Name        0
# Category            0
# Region              0
# State               0
# City                0
# Quantity            0
# Unit Price          0
# Discount %          0
# Sales Amount        0
# Cost Price          0
# Profit              0
# Payment Mode        0
# Delivery Status     0
# Supplier Name       0
# Supplier Email      0
# Stock Left          0
# Auto Reorder        0
# Reorder Quantity    0
# dtype: int64

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# # DATA QUALITY CHECK

# %%
print("**** Data Quality Assessment ****")

# Check for Missing Values
print("\n Missing Values: \n")
missing_data=df.isnull().sum()
print(missing_data[missing_data>0])

# Check for duplicates
print(f"\nDuplicate Rows: {df.duplicated().sum()}")
# Out:
# **** Data Quality Assessment ****
#
#  Missing Values:
#
# Series([], dtype: int64)
#
# Duplicate Rows: 0

# %% [markdown]
# # Data Type Conversion

# %%
# Convert Date columns into date Datatype

df['Order Date'] = pd.to_datetime(
    df['Order Date'],
    format='mixed',
    dayfirst=True
)

df['Ship Date'] = pd.to_datetime(
    df['Ship Date'],
    format='mixed',
    dayfirst=True
)

# Check Conversions

print("\nDate Columns Converted\n")

print(f"Order Date: {df['Order Date'].dtype}")
print(f"Ship Date: {df['Ship Date'].dtype}")

df.head(5)
# Out:
# Date Columns Converted
#
# Order Date: datetime64[ns]
# Ship Date: datetime64[ns]
#   Order Id Order Date  Ship Date Customer Id    Customer Name  \
# 0  ORD1000 2026-06-20 2026-06-26     CUST881      Robert Bath
# 1  ORD1001 2024-12-01 2024-01-19     CUST758      Omaja Verma
# 2  ORD1002 2023-06-12 2023-10-12     CUST547       Waida Kibe
# 3  ORD1003 2026-03-13 2026-03-19     CUST284  Umang Natarajan
# 4  ORD1004 2024-05-15 2024-05-21     CUST148      Zarna Chana
#
#   Customer Segment Product Id   Product Name         Category Region  ...  \
# 0      Home Office    PROD143  Office Chairs        Furniture   West  ...
# 1        Corporate    PROD955        Monitor      Electronics  South  ...
# 2      Home Office    PROD447       Rice Bag          Grocery   West  ...
# 3         Consumer    PROD443    File Folder  Office Supplies  South  ...
# 4         Consumer    PROD638            Pen  Office Supplies   West  ...
#
#   Sales Amount Cost Price    Profit  Payment Mode  Delivery Status  \
# 0       9139.5    6766.17   2373.33          Cash         Returned
# 1      66160.0   35888.32  30271.68           UPI          Pending
# 2      38943.0   29684.69   9258.31          Cash          Pending
# 3      15473.6    9068.18   6405.42           UPI         Returned
# 4       9754.6    5605.26   4149.34          Cash          Pending
#
#                  Supplier Name               Supplier Email  Stock Left  \
# 0                     Mane PLC         shethcharvi@dash.com           4
# 1       Pal, Mishra and Kalita           samesh36@amble.com          22
# 2  Taneja, Aurora and Chaudhry       fhans@balakrishnan.com           0
# 3     Chokshi, Mutti and Borde      mittalhemang@yadav.info          35
# 4                     Mann Ltd  natarajanpallavi@halder.biz          24
#
#   Auto Reorder Reorder Quantity
# 0          Yes               43
# 1           No                0
# 2          Yes               38
# 3           No                0
# 4           No                0
#
# [5 rows x 25 columns]

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
print("==CATEGORICAL COLUMNS==")
categorical_cols=['Customer Segment','Category','Region','Payment Mode','Delivery Status','Auto Reorder']

for col in categorical_cols:
    print(f"\n*--{col}--*")
    print(f"\n{df[col].value_counts()}")

# Visualization

    plt.figure(figsize=(6,6))
    df[col].value_counts().plot(kind='bar',color='pink')
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()
# Out:
# ==CATEGORICAL COLUMNS==
#
# *--Customer Segment--*
#
# Customer Segment
# Consumer       346
# Corporate      337
# Home Office    317
# Name: count, dtype: int64
# *--Category--*
#
# Category
# Office Supplies    265
# Electronics        249
# Furniture          243
# Grocery            243
# Name: count, dtype: int64
# *--Region--*
#
# Region
# North    263
# West     253
# South    248
# East     236
# Name: count, dtype: int64
# *--Payment Mode--*
#
# Payment Mode
# Net Banking    280
# Cash           249
# Credit Card    244
# UPI            227
# Name: count, dtype: int64
# *--Delivery Status--*
#
# Delivery Status
# Returned     262
# Delivered    260
# Pending      254
# Cancelled    224
# Name: count, dtype: int64
# *--Auto Reorder--*
#
# Auto Reorder
# No     797
# Yes    203
# Name: count, dtype: int64

# %% [markdown]
# # Numerical Variable Analysis

# %%
print("\n=== NUMERICAL VARIABLES ===\n")

numerical_cols=['Quantity','Unit Price','Discount %','Sales Amount','Cost Price','Profit','Stock Left','Reorder Quantity']

for col in numerical_cols:
    print(f"\n*---{col}---*\n")
    print(f"Mean : {df[col].mean():.2f}")
    print(f"Median : {df[col].median():.2f}")
    print(f"Standard Deviation : {df[col].std():.2f}")
    print(f"Min : {df[col].min():.2f}")
    print(f"Max : {df[col].max():.2f}")

    # Visulaization

    plt.figure(figsize=(8,4))

    plt.subplot(1,2,1) # Histogram for distribution of Data
    df[col].hist(bins=30,color='lightgreen',alpha=0.7)
    plt.title(f'Distribution of {col}')

    plt.subplot(1,2,2) #Boxplot to check if any outliers present in data or not.
    df.boxplot(column=col)
    plt.title(f"Boxplot of {col}")

    plt.tight_layout()
    plt.show()
# Out:
# === NUMERICAL VARIABLES ===
#
#
# *---Quantity---*
#
# Mean : 5.48
# Median : 5.00
# Standard Deviation : 2.85
# Min : 1.00
# Max : 10.00
# *---Unit Price---*
#
# Mean : 7383.43
# Median : 7211.00
# Standard Deviation : 4315.65
# Min : 108.00
# Max : 14986.00
# *---Discount %---*
#
# Mean : 10.02
# Median : 10.00
# Standard Deviation : 7.21
# Min : 0.00
# Max : 20.00
# *---Sales Amount---*
#
# Mean : 36635.55
# Median : 26675.00
# Standard Deviation : 31298.41
# Min : 5.00
# Max : 149300.00
# *---Cost Price---*
#
# Mean : 20038.88
# Median : 14555.95
# Standard Deviation : 18034.69
# Min : 73.07
# Max : 92437.38
# *---Profit---*
#
# Mean : 16715.65
# Median : 11605.28
# Standard Deviation : 16180.78
# Min : 23.73
# Max : 88222.62
# *---Stock Left---*
#
# Mean : 24.86
# Median : 25.00
# Standard Deviation : 14.68
# Min : 0.00
# Max : 50.00
# *---Reorder Quantity---*
#
# Mean : 7.08
# Median : 0.00
# Standard Deviation : 14.65
# Min : 0.00
# Max : 50.00

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
print("\n== SALES & PROFIT BY CATEGORY ==\n")
category_performance=df.groupby('Category').agg({
    'Sales Amount':'sum',
    'Profit':'sum',
    'Order Id':'count'
}).rename(columns={'Order Id':'Order Count'})

# Creating new column in category performance i.e profit margin..

category_performance['Profit Margin']=(category_performance['Profit']/category_performance['Sales Amount'])*100

print(category_performance)

# Visualization

fig,axes=plt.subplots(2,2,figsize=(15,12))
# Sales By Category
category_performance['Sales Amount'].plot(kind='bar',ax=axes[0,0],color='blue',alpha=0.7)
axes[0,0].set_title("Sales By Category")
axes[0,0].tick_params(axis='x',rotation=30)

# Profit By Category
category_performance['Profit'].plot(kind='bar',ax=axes[0,1],color='blue',alpha=0.7)
axes[0,1].set_title("Profit By Category")
axes[0,1].tick_params(axis='x',rotation=30)

# Order Count by Category
category_performance['Order Count'].plot(kind='bar',ax=axes[1,0],color='blue',alpha=0.7)
axes[1,0].set_title("Order Count By Category")
axes[1,0].tick_params(axis='x',rotation=30)

# Profit Margin by Category
category_performance['Profit Margin'].plot(kind='bar',ax=axes[1,1],color='blue',alpha=0.7)
axes[1,1].set_title("Profit Margin By Category")
axes[1,1].tick_params(axis='x',rotation=30)

plt.tight_layout()
plt.show()
# Out:
# == SALES & PROFIT BY CATEGORY ==
#
#                  Sales Amount      Profit  Order Count  Profit Margin
# Category
# Electronics        9026450.00  4125162.05          249      45.700824
# Furniture          9239671.60  4199516.36          243      45.450927
# Grocery            8636198.20  3822693.92          243      44.263620
# Office Supplies    9733229.65  4568278.28          265      46.934866

# %% [markdown]
# # Regional Performance

# %%
regional_performance=df.groupby('Region').agg({
    "Profit":"sum",
    "Sales Amount":"sum",
    "Order Id":"count",
}).rename(columns={"Order Id":"Order Count"})
regional_performance['Profit Margin']=(regional_performance['Profit']/regional_performance['Sales Amount'])*100
print(f"\n=== Regional Performance === \n{regional_performance}")

fig,axes=plt.subplots(2,2,figsize=(16,8))
regional_performance['Profit'].plot(kind='pie',autopct='%1.1f%%',ax=axes[0,0])
axes[0,0].set_ylabel("")
axes[0,0].set_title("Profit By Region")


regional_performance['Sales Amount'].plot(kind='pie',autopct='%1.1f%%',ax=axes[0,1])
axes[0,1].set_ylabel("")
axes[0,1].set_title("Sales By Region")

regional_performance['Order Count'].plot(kind='pie',autopct='%1.1f%%',ax=axes[1,0])
axes[1,0].set_ylabel("")
axes[1,0].set_title("Order By Region")

regional_performance['Profit Margin'].plot(kind='pie',autopct='%1.1f%%',ax=axes[1,1])
axes[1,1].set_ylabel("")
axes[1,1].set_title("Profit Margin By Region")

plt.tight_layout()
plt.show()
# Out:
# === Regional Performance ===
#             Profit  Sales Amount  Order Count  Profit Margin
# Region
# East    3968920.33    8287805.20          236      47.888678
# North   4297277.20    9581144.05          263      44.851400
# South   4261318.76    9542283.75          248      44.657221
# West    4188134.32    9224316.45          253      45.403194

# %% [markdown]
# # Time Series Analysis

# %%
print(df['Order Date'].dtype)

print("\n===TIME SERIES ANALYSIS===\n")

# Extract Time Components:-

df['Order Month']=df['Order Date'].dt.to_period('M')
df['Order Year']=df['Order Date'].dt.year

print("Months are : \n")
print(df['Order Month'].sample(5))
print("Years are : \n")
df['Order Year'].sample(5)
# Out:
# datetime64[ns]
#
# ===TIME SERIES ANALYSIS===
#
# Months are :
#
# 748    2025-11
# 694    2024-10
# 696    2025-11
# 31     2026-02
# 72     2025-12
# Name: Order Month, dtype: period[M]
# Years are :
# 638    2024
# 696    2025
# 8      2023
# 198    2024
# 858    2023
# Name: Order Year, dtype: int32

# %%
df['Order Date'].sample(10)
# Out:
# 288   2026-01-28
# 355   2026-07-23
# 150   2023-09-11
# 542   2026-06-27
# 399   2023-04-10
# 767   2025-03-23
# 95    2025-02-16
# 235   2023-08-20
# 32    2023-09-11
# 860   2026-12-01
# Name: Order Date, dtype: datetime64[ns]

# %% [markdown]
# # MONTHLY TRENDS

# %%
print("\n== Monthly Trends ==\n")

monthly_trends = df.groupby(['Order Year','Order Month']).agg({
    'Profit': 'sum',
    'Sales Amount': 'sum',
    'Order Id': 'count'
}).rename(columns={'Order Id': 'Order Count'})


# Profit Margin
monthly_trends['Profit Margin'] = (
    monthly_trends['Profit'] / monthly_trends['Sales Amount']
) * 100


# # Correct month order
# month_order = [
#     'January', 'February', 'March', 'April',
#     'May', 'June', 'July', 'August',
#     'September', 'October', 'November', 'December'
# ]

# monthly_trends = monthly_trends.reindex(month_order)

print(monthly_trends)

# Visualization

figure, axes = plt.subplots(4, 1, figsize=(16, 18))


# 1. Monthly Profit
monthly_trends['Profit'].plot(
    kind='line',
    color='green',
    ax=axes[0],
    alpha=0.7,
    marker='o'
)

axes[0].set_title("Monthly Profit")
axes[0].set_xlabel("Order Month")
axes[0].set_ylabel("Profit")
axes[0].ticklabel_format(style='plain', axis='y')
axes[0].grid(True)


# 2. Monthly Sales
monthly_trends['Sales Amount'].plot(
    kind='line',
    color='green',
    ax=axes[1],
    alpha=0.7,
    marker='o'
)

axes[1].set_title("Monthly Sales")
axes[1].set_xlabel("Order Month")
axes[1].set_ylabel("Sales Amount")
axes[1].ticklabel_format(style='plain', axis='y')
axes[1].grid(True)


# 3. Monthly Orders
monthly_trends['Order Count'].plot(
    kind='line',
    color='green',
    ax=axes[2],
    alpha=0.7,
    marker='o'
)

axes[2].set_title("Monthly Orders")
axes[2].set_xlabel("Order Month")
axes[2].set_ylabel("Order Count")
axes[2].grid(True)


# 4. Monthly Profit Margin
monthly_trends['Profit Margin'].plot(
    kind='line',
    color='green',
    ax=axes[3],
    alpha=0.7,
    marker='o'
)

axes[3].set_title("Monthly Profit Margin")
axes[3].set_xlabel("Order Month")
axes[3].set_ylabel("Profit Margin (%)")
axes[3].grid(True)


plt.tight_layout()
plt.show()
# Out:
# == Monthly Trends ==
#
#                            Profit  Sales Amount  Order Count  Profit Margin
# Order Year Order Month
# 2023       2023-01       17025.40      51593.50            3      32.999118
#            2023-02       42771.80     118750.95            1      36.018070
#            2023-03       78553.44     100682.30            3      78.021102
#            2023-04      102516.11     179969.40            4      56.963078
#            2023-05      111025.32     254671.15            7      43.595562
#            2023-06      113107.90     235397.20            5      48.049807
#            2023-07       20706.41      39527.70            4      52.384556
#            2023-08      461697.75     981501.05           22      47.039965
#            2023-09      395746.92     879565.80           27      44.993441
#            2023-10      221403.98     489111.80           17      45.266538
#            2023-11      479865.58     962298.65           26      49.866596
#            2023-12      366151.82     672196.45           19      54.470954
# 2024       2024-01      621719.90    1340768.40           36      46.370417
#            2024-02      428323.12     969764.35           25      44.167753
#            2024-03      400183.10     948249.25           25      42.202311
#            2024-04      476586.37     980709.00           22      48.596104
#            2024-05      425912.93     985461.55           24      43.219640
#            2024-06      477997.63    1039633.70           28      45.977504
#            2024-07      341355.76     705505.95           24      48.384533
#            2024-08      434470.39     980648.45           22      44.304398
#            2024-09      175413.01     388423.30           18      45.160270
#            2024-10      580851.63    1369666.90           39      42.408240
#            2024-11      366357.65     835128.00           27      43.868443
#            2024-12      542605.68    1227906.30           30      44.189502
# 2025       2025-01      572688.63    1199915.25           33      47.727423
#            2025-02      527905.65    1151310.10           24      45.852603
#            2025-03      418307.23     843763.15           24      49.576381
#            2025-04      438019.82    1106134.60           25      39.599143
#            2025-05      499874.03    1005714.55           24      49.703371
#            2025-06      716648.09    1329740.40           39      53.893834
#            2025-07      402041.24     870050.85           26      46.208936
#            2025-08      381528.59     898040.50           28      42.484564
#            2025-09      588457.35    1269346.25           34      46.359088
#            2025-10      423649.64     918292.00           21      46.134524
#            2025-11      557289.88    1369523.20           34      40.692256
#            2025-12      296290.38     715746.50           23      41.395994
# 2026       2026-01      272720.32     676754.20           24      40.298283
#            2026-02      409323.24     976392.00           22      41.922019
#            2026-03      454540.27    1014657.25           36      44.797420
#            2026-04      363160.96     724799.25           19      50.105041
#            2026-05      397678.26     874263.80           23      45.487216
#            2026-06      254265.70     552687.45           21      46.005333
#            2026-07      506707.73    1152213.25           29      43.976905
#            2026-08      118415.75     275442.45            9      42.991104
#            2026-09       73999.61     192115.60            4      38.518272
#            2026-10       86607.07     219717.85            6      39.417403
#            2026-11      149626.81     353427.30            8      42.335951
#            2026-12      123554.76     208370.60            6      59.295678

# %% [markdown]
# # ADVANCED ANALYSIS

# %% [markdown]
# ### 1)Correlation

# %%
print("\n===CORRELATION ANALYSIS===\n")

numerical_df=df[['Quantity','Unit Price','Discount %','Sales Amount','Cost Price','Profit']]
numerical_df

correlation_matrix=numerical_df.corr()
print(correlation_matrix)

plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix,
            annot=True,
            cmap='coolwarm',
            center=0
           )

plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()
# Out:
# ===CORRELATION ANALYSIS===
#
#               Quantity  Unit Price  Discount %  Sales Amount  Cost Price  \
# Quantity      1.000000    0.021240   -0.033809      0.619272    0.577097
# Unit Price    0.021240    1.000000   -0.021017      0.694409    0.655034
# Discount %   -0.033809   -0.021017    1.000000     -0.142869   -0.119434
# Sales Amount  0.619272    0.694409   -0.142869      1.000000    0.916141
# Cost Price    0.577097    0.655034   -0.119434      0.916141    1.000000
# Profit        0.563727    0.624252   -0.148359      0.904573    0.681860
#
#                 Profit
# Quantity      0.563727
# Unit Price    0.624252
# Discount %   -0.148359
# Sales Amount  0.904573
# Cost Price    0.681860
# Profit        1.000000

# %% [markdown]
# # Customer Segment Analysis

# %%
print('\n===Segment Analysis===\n')
segment_analysis=df.groupby('Customer Segment').agg({
    'Sales Amount':['sum','mean'],
    'Profit':['sum','mean'],
    'Order Id':'count',
    'Discount %':'mean'
        
}).round(2)
# print(segment_analysis)
segment_analysis.columns=['Total Sales','Avg Sales','Total Profit','Avg Profit','Order Count','Avg Discount']
print(segment_analysis)
# Visualization

fig, axes=plt.subplots(2,2,figsize=(15,10))

segment_analysis['Total Sales'].plot(kind='bar',ax=axes[0,0],color='lightblue')
axes[0,0].set_title("Total Sales by Customer Segment")
axes[0,0].tick_params(axis='x',rotation=30)

segment_analysis['Total Profit'].plot(kind='bar',ax=axes[0,1],color='lightgreen')
axes[0,1].set_title("Total Profit by Customer Segment")
axes[0,1].tick_params(axis='x',rotation=30)

segment_analysis['Avg Profit'].plot(kind='bar',ax=axes[1,0],color='pink')
axes[1,0].set_title("Avg Profit by Customer Segment")
axes[1,0].tick_params(axis='x',rotation=30)

segment_analysis['Avg Discount'].plot(kind='bar',ax=axes[1,1],color='lightblue')
axes[1,1].set_title("Avg Discount by Customer Segment")
axes[1,1].tick_params(axis='x',rotation=30)

plt.tight_layout()
plt.show()
# Out:
# ===Segment Analysis===
#
#                   Total Sales  Avg Sales  Total Profit  Avg Profit  \
# Customer Segment
# Consumer          12436397.20   35943.34    5584960.76    16141.51
# Corporate         11676894.20   34649.54    5463605.37    16212.48
# Home Office       12522258.05   39502.39    5667084.48    17877.24
#
#                   Order Count  Avg Discount
# Customer Segment
# Consumer                  346         10.66
# Corporate                 337          9.57
# Home Office               317          9.79

# %% [markdown]
# # KEY INSIGHTS AND SUMMARY

# %%
# Summarizing everything in one place now.

print("\n*=== KEY INSIGHTS SUMMARY ===*\n")

# Overall Mtrics

total_sales=df['Sales Amount'].sum()
total_profit=df['Profit'].sum()
total_orders=df['Order Id'].nunique()
avg_profit_margin=(total_profit/total_sales)*100


print(f"\n**OVERALL PERFORMANCE**\n")
print(f"Total Sales ₹{total_sales:,.2f}")
print(f"Total Profit ₹{total_profit:,.2f}")
print(f"Total Orders {total_orders}")
print(f"Average Profit Margin ₹{avg_profit_margin:,.2f}")


# Top Performing Categoreis
top_categories=df.groupby('Category')['Profit'].sum().sort_values(ascending=False)
# print(f"\n\n*****Top Categories By Profit******\n\n{top_categories}")


print("\n\n**Profit Made By Categories**")
for i, (category,profit) in enumerate(top_categories.items(),1):
    print(f"{i}. {category} : {profit:,.2f}")
    

# Regional Performance
best_region=df.groupby('Region')['Profit'].sum().idxmax()
print(f"\n**BEST PERFORMING REGION **: {best_region}")


# Delivery Status
print("\n\n**DELIVERY STATUS**")
best_delivery=df['Delivery Status'].value_counts(normalize=True)*100
for status,percentage in best_delivery.items():
    print(f"{status} : {percentage:,.2f}%")

    
# Customer Segment
best_segment=df.groupby('Customer Segment')['Profit'].sum().idxmax()
print(f"\nMOST PROFITABLE CUSTOMER SEGMENT: {best_segment}")
# Out:
# *=== KEY INSIGHTS SUMMARY ===*
#
#
# **OVERALL PERFORMANCE**
#
# Total Sales ₹36,635,549.45
# Total Profit ₹16,715,650.61
# Total Orders 1000
# Average Profit Margin ₹45.63
#
#
# **Profit Made By Categories**
# 1. Office Supplies : 4,568,278.28
# 2. Furniture : 4,199,516.36
# 3. Electronics : 4,125,162.05
# 4. Grocery : 3,822,693.92
#
# **BEST PERFORMING REGION **: North
#
#
# **DELIVERY STATUS**
# Returned : 26.20%
# Delivered : 26.00%
# Pending : 25.40%
# Cancelled : 22.40%
#
# MOST PROFITABLE CUSTOMER SEGMENT: Home Office

# %% [markdown]
# # EXPORT RESULTS

# %%
analysis_results={
    'total_sales':total_sales,
    'total_profit':total_profit,
    'total_orders':total_orders,
    'avg_profit_margin':avg_profit_margin,
    'top_category':top_categories.index[0],
    'best_region':best_region,
    'best_customer_segment':best_segment
}
# Convert to Data Frame 
results_df=pd.DataFrame([analysis_results])
results_df

results_df.to_csv('superstone_eda_analyis_summary.csv',index=False)
print("\nAnalysis summary saved to 'eda_analysis_summary.csv'")
# Out:
# Analysis summary saved to 'eda_analysis_summary.csv'
